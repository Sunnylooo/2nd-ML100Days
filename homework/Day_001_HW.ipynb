# %% [markdown]
# ##Homework1
# ###Dataset:Heart Disease UCI
#
# 1.Predict heart disease whether you have or not and seek medical treatment in the most appropriate time.
# 2.Creat by several M.D. from different hospital and research institute.
# 3.The data type is csv.
# 4.Using Accuracy or ROC curve.

# %% [markdown]
# ##Homework2
#
# 1.I What passenger thinks about your service.
#   II Brand value and increase
#   III Application user interface optimization
# 2.I Questionnaire from passenger
#   II TIme,Cost,Region,passenger,weather data will influence optimization.
# 3.csv type
# 4.Accuracy , ROC curve

# %% [markdown]
# ##Homework3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 171.288
# The Mean absolute error is 10.490
